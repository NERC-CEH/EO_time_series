# %% [markdown]
# ### Make a sentinel 2 time series
#
# The following runs a few python functions to extract Sentinel 2 NDVI time series data from a point GIS files using google earth engine (GEE) and geopandas. This is potentially useful for looking at annual patterns of NDVI for comparison with other variables and the spatial patterns therein.
#
# The data is returned as a dataframe as well as written to file and can be easily plotted using pandas native functions.

# %%
from src.s2timeseries import S2_ts,_points_to_pixel#, _plotsquare
import geopandas as gpd
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Read in the point shapefile and define a name for the new one.
#
# **Please insert your own one here in place of that below**

# %%
inShp = '/home/ciaran/SOC-D/SOC-D-CSS/CSVeg20161819.shp'

#'example.shp'

outfile = 'example_NDVI_S2.shp'

gdf = gpd.read_file(inShp)

#sanity check
gdf.head()
# Out:
#    SQUARE PLOT_TYPE  PLOT_NUMBE REP_ID REP_ID_NEW START_DATE  COMPLETED_  \
# 0     431         X           4  431X4    30152X4       None  2016-07-21
# 1     317         X           4  317X4    17522X4       None  2016-08-16
# 2     286         U           3  286U3    14342U3       None  2016-05-25
# 3     487         W           2  487W2    36407W2       None  2016-05-25
# 4     258         V           2  258V2    11237V2       None  2016-08-10
#
#      EDITDATE  SLOPE  ASPECT  ...        POINT_X        POINT_Y  DISTURBANC  \
# 0  1899-12-30      2       7  ...  267384.520587  307300.406442           0
# 1  1899-12-30      2       3  ...  237088.149029  247063.153255           0
# 2  1899-12-30      0       0  ...  207598.546770  232269.546730           0
# 3  1899-12-30      0       0  ...  222843.422180  337327.030860           0
# 4  1899-12-30      3       3  ...  252988.913066  217019.359258           0
#
#    BHPH_PLOT  BH_PLOT PH_PLOT BHPH_POLY  BH_POLY  PH_POLY  \
# 0          8        8       0         8        8        0
# 1          5        5       0         5        5        0
# 2          0        0       0         0        0        0
# 3          0        0       0         0        0        0
# 4          3        3       0         3        3        0
#
#                         geometry
# 0  POINT (267384.521 307300.406)
# 1  POINT (237088.149 247063.153)
# 2  POINT (207598.547 232269.547)
# 3  POINT (222843.422 337327.031)
# 4  POINT (252988.913 217019.359)
#
# [5 rows x 91 columns]

# %% [markdown]
# Quickly plot the coords....

# %%
# Sanity check 2.....
uk = gpd.read_file("uk.shp")

base = uk.plot(color='white', edgecolor='black', figsize=(8, 8))

gdf.plot(ax=base, marker='o', color='red', markersize=5);

# %% [markdown]
# The point coordinates should be converted to lat/lon for GEE if not in this format already.
# As this is a UK example we are going from OSGB to lat/lon.

# %%
lons, lats = _points_to_pixel(gdf, espgin='epsg:27700', espgout='epsg:4326')

# %% [markdown]
# ### Now to get the time series
#
# This returns a new geo-dataframe which includes the time series data as a variable and also writes a file to disk.
#
# The reason for inputting the original gdf from above is to retain the correct index for the shapefile for writing purposes. The secondary reason for this procedure is to avoid uploading any data to GEE directly, thus it is just anonamous coordinates.
#
# Some messages will appear updating progress of the task.
#
# Key params
# - ```dist=20``` (the distance in metres from the point - for S2 either 10 or 20)
# - ```stat=max``` (the aggregate stat from which monthly NDVI is derived - either ```max``` or ```perc``` where perc is 95th percentile

# %%
newdf = S2_ts(lons, lats, gdf, collection="COPERNICUS/S2", start_date='2016-01-01',
      end_date='2016-12-31', dist=20, cloud_mask=False, stat='max', 
      cloud_perc=100, para=True, outfile=outfile)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 301 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 949 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 1336 out of 1336 | elapsed:  2.9min finished

# %%
Have a look and see the ndvi vals are there as expected - they will be under date headings.

# %%
newdf.head()
# Out:
#    key_0  SQUARE PLOT_TYPE  PLOT_NUMBE REP_ID REP_ID_NEW START_DATE  \
# 0      0     431         X           4  431X4    30152X4       None
# 1      1     317         X           4  317X4    17522X4       None
# 2      2     286         U           3  286U3    14342U3       None
# 3      3     487         W           2  487W2    36407W2       None
# 4      4     258         V           2  258V2    11237V2       None
#
#    COMPLETED_    EDITDATE  SLOPE  ...  2016-03-31  2016-04-30  2016-05-31  \
# 0  2016-07-21  1899-12-30      2  ...    0.495778    0.555221    0.552193
# 1  2016-08-16  1899-12-30      2  ...    0.496779    0.657786    0.824139
# 2  2016-05-25  1899-12-30      0  ...    0.419804    0.480563    0.643175
# 3  2016-05-25  1899-12-30      0  ...    0.499434    0.693267    0.779291
# 4  2016-08-10  1899-12-30      3  ...    0.634177    0.589888    0.821421
#
#    2016-06-30  2016-07-31  2016-08-31 2016-09-30 2016-10-31  2016-11-30  \
# 0    0.573616    0.759211    0.694066   0.667900   0.615901    0.636882
# 1    0.859921    0.619800    0.237031   0.508229   0.274297    0.539101
# 2    0.665627    0.751192    0.674197   0.184601   0.497379    0.385766
# 3    0.770000    0.743215    0.766930   0.741021   0.616499    0.527897
# 4    0.602764    0.821294    0.641273   0.773778   0.513043    0.610597
#
#    2016-12-31
# 0    0.596933
# 1    0.074063
# 2    0.104212
# 3    0.451981
# 4    0.481593
#
# [5 rows x 104 columns]

# %% [markdown]
# Now with a new gpd it is easy enough to plot the spatial pattern of ndvi.

# %%
fig, axes = plt.subplots(ncols=3, figsize=(10, 10))

dates = ["2016-03-31", "2016-05-31", "2016-11-30"]

for idx, d in enumerate(dates):

    newdf.plot(column=d, ax=axes[idx], legend=True, legend_kwds={'orientation': "horizontal"})

# %% [markdown]
# ### Having processed gained ndvi attributes, it is easy to plot the ndvi time series with a bit of reshaping per survey area
#
# As we are using survey data where plots are grouped by the attribute "SQUARE", we can plot the ndvi time series for each one with the function below (also in src).

# %%
def _plotsquare(df, square):
    
    # Quick & dirty time series plotting

    sqr = df[df.SQUARE==square]
    
    yrcols = [y for y in sqr.columns if '2016' in y]
    
    ndplotvals = sqr[yrcols]
    
    ndplotvals.transpose().plot.line()

# %% [markdown]
# The resulting plot.....

# %%
_plotsquare(newdf, 637)
